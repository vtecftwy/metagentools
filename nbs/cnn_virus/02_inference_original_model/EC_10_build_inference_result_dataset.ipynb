# %% [markdown]
# # Build inference result dataset

# %% [markdown]
# **Objective**: create a dataset with the result of inference using simulated reads using  a subset/all the sequences as reference.
#
# **Constraints**: cannot load the totalily of the data into memory for inference because there are to many reads:
# - estimated 50k reads per sequence. for the 3k sequences, this means 150 million reads to handle !
#
# **Pipeline Idea**:
#
# Use a large fast file and iterate over manageble chuncks. For each chunck:
# - create a fasta file for the chunk (`.fa`)
# - create simreads with Art Illumina (`fq`, `aln`)
# - preprocess simreads into ds and info
# - use model to infer taxonomy and position
# - build the inference result dataset including"
#     - predicted result
#     - ref sequence metadata
#     - position ground truth
# - save partial inference result dataset as parquet
#
# When iteration is done:
# - merge all partial inference result datasets into one single dataset
#
#
# **Intermediate steps**: use groups of sequence to experiments and still get some statistically relevant info

# %% [markdown]
# # Setup

# %%
from ecutilities.ipython import nb_setup, pandas_nrows_ncols
nb_setup()
# Out:
# Set autoreload mode

# %%
import numpy as np
import os
import pandas as pd
import tempfile
from nbdev import show_doc
from pathlib import Path
from pprint import pprint
from metagentools.art import ArtIllumina
from metagentools.cnn_virus.data import FastaFileReader, FastaFileIterator, parse_metadata_fasta_cov

# %% [markdown]
# # Build pipeline

# %% [markdown]
# **Pipeline Idea**:
#
# Use a large fasta file and iterate over manageble chuncks.
#
# For each chunck:
#
# - create a fasta file for the chunk (`.fa`)
# - create simreads with Art Illumina (`fq`, `aln`)
# - preprocess simreads into model input data and metadata
# - use model to infer taxonomy and position
# - build the inference result dataset including"
#     - predicted result
#     - ref sequence metadata
#     - position ground truth
# - save partial inference result dataset as parquet
#
# When iteration is done:
# - merge all partial inference result datasets into one single dataset

# %% [markdown]
# ## Imports and paths

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # or any {'0', '1', '2'}

# %%
from ecutilities.core import validate_path
from metagentools.art import ArtIllumina, _run
from metagentools.core import TextFileBaseIterator
from metagentools.cnn_virus.architecture import load_model
from metagentools.cnn_virus.data import create_infer_ds_from_fastq, strings_to_tensors, FastqFileReader, AlnFileReader
from tensorflow.data import TextLineDataset

# %% [markdown]
# Path to source fasta file

# %%
p2cov_data = Path(f"../../../data/cov_data/").resolve()
groups_subdir = 'groups_1'
p2groups = p2cov_data / groups_subdir
assert p2groups.is_dir()

# p2refs = p2groups / 'seqs_alphacoronavirus.fa'
# p2refs = p2groups / 'seqs_porcine_deltacoronavirus.fa'
p2refs = p2cov_data / 'cov_virus_sequences.fa'

# %% [markdown]
# ## Pipeline Functions

# %%
def create_small_fasta(chunck):
    print(f">>> Preparing small fasta file")
    with open(p2fa, 'w') as fp:
        fp.write(chunck)
#     with open(p2fa, 'r') as fp:
#         print(fp.readline()[:80])

# %%
def simreads():
    print(f">>> Simulating reads")
    app = 'art_illumina'
    art = ArtIllumina(path2app=app, input_dir=p2tdir, output_dir=p2tdir, app_in_system_path=True)
    art.sim_reads(
        input_file=p2fa.name, output_seed='simreads',
        sim_type='single', read_length=50, fold=10, 
        overwrite=True,
        print_output=False,
    )
    return art

# %%
def build_input_files(art):
    print(f">>> Preparing input file for cnn virus model")
    p2aln, p2fastq = sorted(art.get_last_output_files())
    p2ds, reads_info = create_infer_ds_from_fastq(p2fastq, output_dir=p2tdir, overwrite_ds=True, nsamples=None)
    return p2ds, reads_info

# %% [markdown]
# - https://stackoverflow.com/questions/39758094/clearing-tensorflow-gpu-memory-after-model-execution

# %%
def predict(p2ds):
    print(f">>> Running original model in inference")
    p2saved = Path('/home/vtec/projects/bio/metagentools/data/saved/cnn_virus_original/pretrained_model.h5')
    text_ds = TextLineDataset(p2ds).batch(32)
    ds = text_ds.map(strings_to_tensors)
    model = load_model(p2saved)
    prob_preds = model.predict(ds, verbose=1)
    lbl_preds = np.argmax(prob_preds[0], axis=1)
    return lbl_preds

# %%
def save_result_ds(preds, reads_info):
    print(f">>> Saving inference result DataFrame for this iteration")
    p2cov_results = Path('/home/vtec/projects/bio/metagentools/data/cov_results/cnn_virus')
    data = np.column_stack((reads_info, preds))
    cols = 'refseqid read_position refseq_strand pred_label'.split(' ')
    results = pd.DataFrame(data=data[:, 1:], index=data[:, 0], columns=cols)
    p2results = p2cov_results / f"results_{i:04d}_{(p2tdir.name)}.parquet"
    results.to_parquet(p2results)
    return p2results

# %% [markdown]
# ## Run pipeline

# %%
nseqs = 50
it = TextFileBaseIterator(path=p2refs, nlines= 2 * nseqs)

# create a temporary directory where to save intermediate files
tdir = tempfile.TemporaryDirectory(prefix='infer_', suffix=None, dir=Path().resolve().absolute())
p2tdir = Path(tdir.name)
print(p2tdir)
p2fa =  p2tdir / 'small_fasta.fa'
assert p2tdir.is_dir()

infresult_paths = []

# for each iteration:
for i, chunck in enumerate(it):
    print(f"Iteration {i+1}")
    create_small_fasta(chunck)
    art = simreads()
    p2fastq, p2aln = art.get_last_output_files()
    fastq = FastqFileReader(p2fastq)
    aln = AlnFileReader(p2aln)
    p2ds, reads_info = build_input_files(art)
    preds = predict(p2ds)
    p = save_result_ds(preds, reads_info)
    infresult_paths.append(p)

tdir.cleanup()
# Out:
# /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Iteration 1
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 281,040 reads
# >>> Running original model in inference
# 8783/8783 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 2
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,447 reads
# >>> Running original model in inference
# 8921/8921 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 3
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,462 reads
# >>> Running original model in inference
# 8952/8952 [==============================] - 184s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 4
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,148 reads
# >>> Running original model in inference
# 8974/8974 [==============================] - 184s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 5
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,417 reads
# >>> Running original model in inference
# 8951/8951 [==============================] - 184s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 6
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 284,781 reads
# >>> Running original model in inference
# 8900/8900 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 7
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 279,240 reads
# >>> Running original model in inference
# 8727/8727 [==============================] - 179s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 8
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 284,666 reads
# >>> Running original model in inference
# 8896/8896 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 9
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,188 reads
# >>> Running original model in inference
# 8944/8944 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 10
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,202 reads
# >>> Running original model in inference
# 8976/8976 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 11
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,980 reads
# >>> Running original model in inference
# 8969/8969 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 12
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 289,154 reads
# >>> Running original model in inference
# 9037/9037 [==============================] - 184s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 13
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 284,460 reads
# >>> Running original model in inference
# 8890/8890 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 14
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 282,776 reads
# >>> Running original model in inference
# 8837/8837 [==============================] - 182s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 15
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 282,510 reads
# >>> Running original model in inference
# 8829/8829 [==============================] - 179s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 16
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,805 reads
# >>> Running original model in inference
# 9026/9026 [==============================] - 185s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 17
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 283,560 reads
# >>> Running original model in inference
# 8862/8862 [==============================] - 178s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 18
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 280,368 reads
# >>> Running original model in inference
# 8762/8762 [==============================] - 179s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 19
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,320 reads
# >>> Running original model in inference
# 9010/9010 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 20
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,010 reads
# >>> Running original model in inference
# 8970/8970 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 21
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 280,445 reads
# >>> Running original model in inference
# 8764/8764 [==============================] - 178s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 22
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,120 reads
# >>> Running original model in inference
# 8973/8973 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 23
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,663 reads
# >>> Running original model in inference
# 8927/8927 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 24
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,398 reads
# >>> Running original model in inference
# 8919/8919 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 25
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,464 reads
# >>> Running original model in inference
# 8952/8952 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 26
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,950 reads
# >>> Running original model in inference
# 8968/8968 [==============================] - 184s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 27
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,676 reads
# >>> Running original model in inference
# 8990/8990 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 28
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 289,909 reads
# >>> Running original model in inference
# 9060/9060 [==============================] - 184s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 29
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 289,625 reads
# >>> Running original model in inference
# 9051/9051 [==============================] - 185s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 30
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,206 reads
# >>> Running original model in inference
# 8944/8944 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 31
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,650 reads
# >>> Running original model in inference
# 8927/8927 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 32
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,953 reads
# >>> Running original model in inference
# 9030/9030 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 33
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,383 reads
# >>> Running original model in inference
# 9012/9012 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 34
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,900 reads
# >>> Running original model in inference
# 8966/8966 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 35
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 281,120 reads
# >>> Running original model in inference
# 8785/8785 [==============================] - 180s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 36
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 282,590 reads
# >>> Running original model in inference
# 8831/8831 [==============================] - 179s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 37
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,657 reads
# >>> Running original model in inference
# 9021/9021 [==============================] - 184s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 38
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,207 reads
# >>> Running original model in inference
# 8913/8913 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 39
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 283,670 reads
# >>> Running original model in inference
# 8865/8865 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 40
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,195 reads
# >>> Running original model in inference
# 8913/8913 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 41
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,870 reads
# >>> Running original model in inference
# 8934/8934 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 42
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,770 reads
# >>> Running original model in inference
# 8931/8931 [==============================] - 184s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 43
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,113 reads
# >>> Running original model in inference
# 8973/8973 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 44
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 290,890 reads
# >>> Running original model in inference
# 9091/9091 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 45
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,855 reads
# >>> Running original model in inference
# 8933/8933 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 46
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,310 reads
# >>> Running original model in inference
# 9010/9010 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 47
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,262 reads
# >>> Running original model in inference
# 8915/8915 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 48
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 282,522 reads
# >>> Running original model in inference
# 8829/8829 [==============================] - 178s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 49
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,780 reads
# >>> Running original model in inference
# 9025/9025 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 50
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 283,839 reads
# >>> Running original model in inference
# 8870/8870 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 51
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,890 reads
# >>> Running original model in inference
# 9028/9028 [==============================] - 185s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 52
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 284,381 reads
# >>> Running original model in inference
# 8887/8887 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 53
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 283,748 reads
# >>> Running original model in inference
# 8868/8868 [==============================] - 179s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 54
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,116 reads
# >>> Running original model in inference
# 8910/8910 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 55
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 290,368 reads
# >>> Running original model in inference
# 9074/9074 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 56
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 287,717 reads
# >>> Running original model in inference
# 8992/8992 [==============================] - 184s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 57
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 290,342 reads
# >>> Running original model in inference
# 9074/9074 [==============================] - 185s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 58
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,246 reads
# >>> Running original model in inference
# 8914/8914 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 59
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,246 reads
# >>> Running original model in inference
# 8946/8946 [==============================] - 179s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 60
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,849 reads
# >>> Running original model in inference
# 8965/8965 [==============================] - 184s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 61
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 284,466 reads
# >>> Running original model in inference
# 8890/8890 [==============================] - 181s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 62
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 288,440 reads
# >>> Running original model in inference
# 9014/9014 [==============================] - 185s 21ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 63
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,101 reads
# >>> Running original model in inference
# 8941/8941 [==============================] - 180s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 64
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 286,544 reads
# >>> Running original model in inference
# 8955/8955 [==============================] - 183s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 65
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 285,065 reads
# >>> Running original model in inference
# 8909/8909 [==============================] - 182s 20ms/step
# >>> Saving inference result DataFrame for this iteration
# Iteration 66
# >>> Preparing small fasta file
# >>> Simulating reads
# Ready to operate with art: art_illumina
# Input files from : /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# Output files to :  /home/vtec/projects/bio/metagentools/nbs/cnn_virus/02_inference_original_model/infer_s4gjodd8
# >>> Preparing input file for cnn virus model
# Dataset with 296,904 reads
# >>> Running original model in inference
# 9279/9279 [==============================] - 190s 20ms/step
# >>> Saving inference result DataFrame for this iteration

# %% [markdown]
# # Others
